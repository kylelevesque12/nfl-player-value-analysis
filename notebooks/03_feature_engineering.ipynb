# %% [markdown]
# # Value Score Engineering
#
# The goal of this notebook is to use the cleaned player-season dataset to create position-adjusted value scores for NFL offensive skill players.
#
# The value scores are built separately for quarterbacks and non-quarterbacks due to differences in production between these positional groups. Each score is standardized within season-position groups so that players are compared against others at the same position in the same season.
